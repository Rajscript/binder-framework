# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("Value_of_Energy_Cost_Savings_Program_Savings_for_Businesses_-_FY2020.csv")
dNTA=pd.read_csv("NTA.csv")

# %%
df
# Out:
#                                  Company Name    company contact  \
# 0                              1 State Street      David Neiburg
# 1                              100 Church LLC  Edward A. Carroll
# 2                        100 Wall Investments       Jerry Branam
# 3                 1-10 Bush Terminal Owner LP     Andrew Kimball
# 4    120 Broadway Acquisitions JV, LLC (Ldmk)        Carl Letich
# ..                                        ...                ...
# 445                         WONTON FOOD, INC.         DONALD LAU
# 446                                Wood Works       Gordon Brawm
# 447           WorldWide Plumbing Supply, Inc.    Surie Lefkowitz
# 448                         WUD Furniture LLC     Keren Springer
# 449                       Wurtec Incorporated          Bill Popp
#
#                  company email company phone                Address  \
# 0       eskoblo@energyspec.com    7186779077          1114 Avenue J
# ...

# %%
dNTA
# Out:
#                                                  NTA  Number_of_business  \
# 0                  Battery Park City-Lower Manhattan                   9
# 1                                     Bushwick South                  10
# 2           Carroll Gardens-Columbia Street-Red Hook                  11
# 3                                      College Point                   7
# 4                                Crown Heights North                   9
# 5   DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill                  10
# 6                                      East New York                   9
# 7                                  East Williamsburg                  11
# 8                                         Greenpoint                  14
# 9               Hunters Point-Sunnyside-West Maspeth                  75
# 10                                       Hunts Point                  13
# 11                                    Manhattanville                   9
# ...

# %%
sns.scatterplot(data=dNTA, x="TotalJobsCreated", y="Mean_Job_Savings")
# Out:
# <AxesSubplot:xlabel='TotalJobsCreated', ylabel='Mean_Job_Savings'>

# %%
splot=sns.scatterplot(data=dNTA, x="TotalJobsCreated", y="Mean_Job_Savings")
splot.set(yscale="log")
# Out:
# [None]

# %%
dNTA['Mean_Job_Savings'].hist(bins=130)
# Out:
# <AxesSubplot:>

# %%
df['month'] = pd.DatetimeIndex(df['Effective Date']).month

# %%
res=df.groupby('month')['Job created'].agg(TotalJobsCreated='sum')

# %%
res
# Out:
#        TotalJobsCreated
# month
# 1                   0.0
# 2                  27.0
# 3                  20.0
# 4                   2.0
# 5                   2.0
# 6                  63.0
# 7                  20.0
# 8                   0.0
# 9                   0.0
# 10                  0.0
# 11                  5.0
# 12                 10.0

# %%
sns.lineplot(data=res, x='month', y='TotalJobsCreated')
# Out:
# <AxesSubplot:xlabel='month', ylabel='TotalJobsCreated'>
